# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../src')
from tools import *
import pickle
import pandas as pd

# %%
fname_query = "../data/cacm/cacm.qry"
fname_rel = "../data/cacm/cacm.rel"

# %%
queryParser = QueryParser()
queryParser.buildQueriesCollection(fname_query)
queryParser.buildJudgementsCollection(fname_rel)
# Out:
# Construction de la collection de requêtes achevée : la collection ../data/cacm/cacm.qry contient 64 requêtes.
# Construction de la collection de jugements de pertinence achevée : la collection ../data/cacm/cacm.rel contient 52 requêtes.

# %%
queryParser.displayQueriesCollection()
# Out:
# --> Requête 1
# 	Texte : What articles exist which deal with TSS (Time Sharing System), anoperating system for IBM computers?
# -------------------------------------
# --> Requête 2
# 	Texte : I am interested in articles written either by Prieve or Udo Pooch
# -------------------------------------
# --> Requête 3
# 	Texte : Intermediate languages used in construction of multi-targeted compilers; TCOLL
# -------------------------------------
# --> Requête 4
# 	Texte : I'm interested in mechanisms for communicating between disjoint processes,possibly, but not exclusively, in a distributed environment.  I wouldrather see descriptions of complete mechanisms, with or without implementations,as opposed to theoretical work on the abstract problem.  Remote procedurecalls and message-passing are examples of my interests.
# -------------------------------------
# --> Requête 5
# ...

# %%
queryParser.displayJudgementsCollection()
# Out:
# --> Requête 1
# 	Texte : What articles exist which deal with TSS (Time Sharing System), anoperating system for IBM computers?
# 	Documents pertinents :
# 	2020 (1)
# 	1410 (1)
# 	1572 (1)
# 	1605 (1)
# 	2358 (1)
# -------------------------------------
# --> Requête 2
# 	Texte : I am interested in articles written either by Prieve or Udo Pooch
# 	Documents pertinents :
# 	2434 (1)
# 	3078 (1)
# 	2863 (1)
# -------------------------------------
# --> Requête 3
# 	Texte : Intermediate languages used in construction of multi-targeted compilers; TCOLL
# 	Documents pertinents :
# 	2290 (1)
# 	2923 (1)
# 	1947 (1)
# 	1613 (1)
# 	1134 (1)
# 	1807 (1)
# -------------------------------------
# --> Requête 4
# ...
