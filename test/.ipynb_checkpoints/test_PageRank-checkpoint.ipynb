# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../src')
from tools import *
import pickle
import pandas as pd

# %% [markdown]
# ### Parsing et indexation de cacm.txt

# %%
parser = Parser()
parser.buildDocCollection("../data/cacm/cacm.txt")
docs = parser.getCollection()

indexer = IndexerSimple(parser.getSource())
indexer.indexation(docs)
# Out:
# Construction achevée : la collection ../data/cacm/cacm.txt contient 4203 documents.
# Indexation de la collection ../data/cacm/cacm.txt achevée

# %% [markdown]
# ### Parsing des requêtes et jugements de pertinence

# %%
fname_query = "../data/cacm/cacm.qry"
fname_rel = "../data/cacm/cacm.rel"
qParser = QueryParser()
qParser.buildQueriesCollection(fname_query)
qParser.buildJudgementsCollection(fname_rel)
# Out:
# Construction de la collection de requêtes achevée : la collection ../data/cacm/cacm.qry contient 64 requêtes.
# Construction de la collection de jugements de pertinence achevée : la collection ../data/cacm/cacm.rel contient 52 requêtes.

# %% [markdown]
# ### Application de Page Rank pour une requête, avec le modèle OkapiBM25

# %%
query = qParser.getQueriesCollection()[1]
print(query)
# Out:
# What articles exist which deal with TSS (Time Sharing System), anoperating system for IBM computers?

# %%
model = OkapiBM25(indexer)

# %%
n = 20
k = 5

# %%
pageRank = PageRank(model, n, k)
scores = pageRank.compute_pageRank(query, parser)

# %%
pd.DataFrame(scores).rename(columns={0:'Identifiant du document',1:'Score (Page Rank)'})
# Out:
#      Identifiant du document  Score (Page Rank)
# 0                     1751.0       4.771303e-03
# 1                     2629.0       4.736264e-03
# 2                     1781.0       4.725415e-03
# 3                     1901.0       4.715389e-03
# 4                      118.0       4.688243e-03
# 5                     1844.0       4.683391e-03
# 6                     3184.0       4.683325e-03
# 7                      196.0       4.677990e-03
# 8                     2373.0       4.677721e-03
# 9                     2095.0       4.675319e-03
# 10                      53.0       4.675310e-03
# 11                     818.0       4.673534e-03
# 12                    2863.0       4.669426e-03
# 13                    3023.0       4.669357e-03
# 14                    1491.0       4.666830e-03
# 15                    2358.0       4.663916e-03
# 16                     142.0       4.663776e-03
# 17                    2218.0       4.663749e-03
# 18                      31.0       4.663244e-03
# 19                     143.0       4.661974e-03
# 20                    2619.0       4.659822e-03
# 21                    1572.0       4.659329e-03
# 22                     205.0       4.656312e-03
# 23                    1007.0       4.654274e-03
# 24                    1892.0       4.651842e-03
# 25                      61.0       4.651730e-03
# 26                    2669.0       4.651640e-03
# 27                    2374.0       4.650227e-03
# 28                    2380.0       4.648990e-03
# 29                    2344.0       4.647391e-03
# ..                       ...                ...
# 970                   1316.0       1.087753e-07
# 971                   1757.0       1.087753e-07
# 972                   1761.0       1.087753e-07
# 973                    635.0       1.087753e-07
# 974                   1767.0       1.087753e-07
# 975                   1768.0       1.087753e-07
# 976                   1771.0       1.087753e-07
# 977                   1772.0       1.087753e-07
# 978                   1773.0       1.087753e-07
# 979                   1774.0       1.087753e-07
# 980                   1785.0       1.087753e-07
# 981                   1786.0       1.087753e-07
# 982                   1792.0       1.087753e-07
# 983                   1796.0       1.087753e-07
# 984                   1799.0       1.087753e-07
# 985                   1801.0       1.087753e-07
# 986                   1151.0       1.087753e-07
# 987                   1807.0       1.087753e-07
# 988                    265.0       1.087753e-07
# 989                   1824.0       1.087753e-07
# 990                   1825.0       1.087753e-07
# 991                   1826.0       1.087753e-07
# 992                   1827.0       1.087753e-07
# 993                   1828.0       1.087753e-07
# 994                   1834.0       1.087753e-07
# 995                   1836.0       1.087753e-07
# 996                   1841.0       1.087753e-07
# 997                   1842.0       1.087753e-07
# 998                    307.0       1.087753e-07
# 999                   2356.0       1.087753e-07
#
# [1000 rows x 2 columns]
